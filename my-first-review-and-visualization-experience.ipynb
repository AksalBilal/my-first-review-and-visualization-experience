# %% [markdown]
# **Hello,
# I'm going to try to examine a data set today.**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for data visulizations
import seaborn as sns  # to draw a heat map

import os
print(os.listdir("../input"))
data=pd.read_csv('../input/Pokemon.csv')  #import data
# Out:
# ['Pokemon.csv']

# %% [markdown]
# to get information about the database we are calling the info function.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# let's see the columns of the csv file that we added

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# We call the 'shape' function to find out how many of our data and the number of columns.

# %%
data.shape
# Out:
# (800, 13)

# %% [markdown]
# Let's use the Head Function to see the first 10 values of our data.

# %%
data.head()
# Out:
#    #                   Name Type 1    ...     Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass    ...        45           1      False
# 1  2                Ivysaur  Grass    ...        60           1      False
# 2  3               Venusaur  Grass    ...        80           1      False
# 3  3  VenusaurMega Venusaur  Grass    ...        80           1      False
# 4  4             Charmander   Fire    ...        65           1      False
#
# [5 rows x 13 columns]

# %% [markdown]
# Looking at the above table, we see that the column '#' is unnecessary.
# Let's delete this column.

# %%
data.drop('#',axis=1,inplace=True)

# %% [markdown]
# Let's look at the database again.

# %%
data.head(10)
# Out:
#                         Name Type 1    ...     Generation  Legendary
# 0                  Bulbasaur  Grass    ...              1      False
# 1                    Ivysaur  Grass    ...              1      False
# 2                   Venusaur  Grass    ...              1      False
# 3      VenusaurMega Venusaur  Grass    ...              1      False
# 4                 Charmander   Fire    ...              1      False
# 5                 Charmeleon   Fire    ...              1      False
# 6                  Charizard   Fire    ...              1      False
# 7  CharizardMega Charizard X   Fire    ...              1      False
# 8  CharizardMega Charizard Y   Fire    ...              1      False
# 9                   Squirtle  Water    ...              1      False
#
# [10 rows x 12 columns]

# %% [markdown]
# We use a histogram to see the distribution of our data.

# %%
# Histogram
# bins = number of bar in figure
data.plot(kind = 'hist',bins = 50)
plt.show()

# %% [markdown]
# We call the describe function to see the mathematical ratios (total number, average, standard deviation, minimum value, lower end value, median, upper end value, maximum value) of our database.

# %%
data.describe()
# Out:
#            Total          HP     ...           Speed  Generation
# count  800.00000  800.000000     ...      800.000000   800.00000
# mean   435.10250   69.258750     ...       68.277500     3.32375
# std    119.96304   25.534669     ...       29.060474     1.66129
# min    180.00000    1.000000     ...        5.000000     1.00000
# 25%    330.00000   50.000000     ...       45.000000     2.00000
# 50%    450.00000   65.000000     ...       65.000000     3.00000
# 75%    515.00000   80.000000     ...       90.000000     5.00000
# max    780.00000  255.000000     ...      180.000000     6.00000
#
# [8 rows x 8 columns]

# %% [markdown]
# We are calling the corr function to examine the correlation in our data.

# %%
data.corr()
# Out:
#                Total        HP    ...      Generation  Legendary
# Total       1.000000  0.618748    ...        0.048384   0.501758
# HP          0.618748  1.000000    ...        0.058683   0.273620
# Attack      0.736211  0.422386    ...        0.051451   0.345408
# Defense     0.612787  0.239622    ...        0.042419   0.246377
# Sp. Atk     0.747250  0.362380    ...        0.036437   0.448907
# Sp. Def     0.717609  0.378718    ...        0.028486   0.363937
# Speed       0.575943  0.175952    ...       -0.023121   0.326715
# Generation  0.048384  0.058683    ...        1.000000   0.079794
# Legendary   0.501758  0.273620    ...        0.079794   1.000000
#
# [9 rows x 9 columns]

# %% [markdown]
# After the Corr function, we use the heatmap library to view the correlation distribution in detail by subtracting our heat map.

# %%
#correlation map
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data.corr(), annot=True, linewidths=.5,linecolor='w',cmap="YlGnBu", fmt= '.2f',ax=ax)
plt.show()

# %% [markdown]
# We use the Scatter plot to examine the distribution between 'Attack' and 'Defense' columns.

# %%
plt.plot(data.Attack,data.Defense,color='orange')
plt.xlabel('Attack')         # Name of X
plt.ylabel('Defense')        # Name of Y
plt.title('Attack-Defense Scatter Plot') #Name of Title
plt.gcf().set_size_inches((10, 10)) #To enlarge the size of the image.
plt.show() #do not forget that when you drawing plot

# %%
# Scatter Plot 
# x = Attack, y = Defense
data.plot(kind='scatter', x='Attack', y='Defense',alpha = 0.5,color = 'blue')
plt.xlabel('Attack')         # Name of X
plt.ylabel('Defense')        # Name of Y
plt.title('Attack-Defense Scatter Plot') #Name of Title
plt.gcf().set_size_inches((10, 10)) #To enlarge the size of the image.
plt.show() #do not forget that when you drawing plot

# %% [markdown]
# Let's take a look at the data set.

# %%
data
# Out:
#                           Name    Type 1    ...     Generation  Legendary
# 0                    Bulbasaur     Grass    ...              1      False
# 1                      Ivysaur     Grass    ...              1      False
# 2                     Venusaur     Grass    ...              1      False
# 3        VenusaurMega Venusaur     Grass    ...              1      False
# 4                   Charmander      Fire    ...              1      False
# 5                   Charmeleon      Fire    ...              1      False
# 6                    Charizard      Fire    ...              1      False
# 7    CharizardMega Charizard X      Fire    ...              1      False
# 8    CharizardMega Charizard Y      Fire    ...              1      False
# 9                     Squirtle     Water    ...              1      False
# 10                   Wartortle     Water    ...              1      False
# 11                   Blastoise     Water    ...              1      False
# 12     BlastoiseMega Blastoise     Water    ...              1      False
# 13                    Caterpie       Bug    ...              1      False
# 14                     Metapod       Bug    ...              1      False
# 15                  Butterfree       Bug    ...              1      False
# 16                      Weedle       Bug    ...              1      False
# 17                      Kakuna       Bug    ...              1      False
# 18                    Beedrill       Bug    ...              1      False
# 19       BeedrillMega Beedrill       Bug    ...              1      False
# 20                      Pidgey    Normal    ...              1      False
# 21                   Pidgeotto    Normal    ...              1      False
# 22                     Pidgeot    Normal    ...              1      False
# 23         PidgeotMega Pidgeot    Normal    ...              1      False
# 24                     Rattata    Normal    ...              1      False
# 25                    Raticate    Normal    ...              1      False
# 26                     Spearow    Normal    ...              1      False
# 27                      Fearow    Normal    ...              1      False
# 28                       Ekans    Poison    ...              1      False
# 29                       Arbok    Poison    ...              1      False
# ..                         ...       ...    ...            ...        ...
# 770                    Sylveon     Fairy    ...              6      False
# 771                   Hawlucha  Fighting    ...              6      False
# 772                    Dedenne  Electric    ...              6      False
# 773                    Carbink      Rock    ...              6      False
# 774                      Goomy    Dragon    ...              6      False
# 775                    Sliggoo    Dragon    ...              6      False
# 776                     Goodra    Dragon    ...              6      False
# 777                     Klefki     Steel    ...              6      False
# 778                   Phantump     Ghost    ...              6      False
# 779                  Trevenant     Ghost    ...              6      False
# 780      PumpkabooAverage Size     Ghost    ...              6      False
# 781        PumpkabooSmall Size     Ghost    ...              6      False
# 782        PumpkabooLarge Size     Ghost    ...              6      False
# 783        PumpkabooSuper Size     Ghost    ...              6      False
# 784      GourgeistAverage Size     Ghost    ...              6      False
# 785        GourgeistSmall Size     Ghost    ...              6      False
# 786        GourgeistLarge Size     Ghost    ...              6      False
# 787        GourgeistSuper Size     Ghost    ...              6      False
# 788                   Bergmite       Ice    ...              6      False
# 789                    Avalugg       Ice    ...              6      False
# 790                     Noibat    Flying    ...              6      False
# 791                    Noivern    Flying    ...              6      False
# 792                    Xerneas     Fairy    ...              6       True
# 793                    Yveltal      Dark    ...              6       True
# 794           Zygarde50% Forme    Dragon    ...              6       True
# 795                    Diancie      Rock    ...              6       True
# 796        DiancieMega Diancie      Rock    ...              6       True
# 797        HoopaHoopa Confined   Psychic    ...              6       True
# 798         HoopaHoopa Unbound   Psychic    ...              6       True
# 799                  Volcanion      Fire    ...              6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# Let's take Pokemon into separate data sets according to their types.

# %%
#sort by type
Water= data[data["Type 1"]=="Water"]
Steel= data[data["Type 1"]=="Steel"]
Rock= data[data["Type 1"]=="Rock"]
Psychic= data[data["Type 1"]=="Psychic"]
Poison= data[data["Type 1"]=="Water"]
Normal= data[data["Type 1"]=="Normal"]
Ice= data[data["Type 1"]=="Ice"]
Ground= data[data["Type 1"]=="Ground"]
Grass= data[data["Type 1"]=="Grass"]
Ghost= data[data["Type 1"]=="Ghost"]
Fire= data[data["Type 1"]=="Fire"]
Fighting= data[data["Type 1"]=="Fighting"]
Fairy= data[data["Type 1"]=="Fairy"]
Electric= data[data["Type 1"]=="Electric"]
Dragon= data[data["Type 1"]=="Dragon"]
Dark= data[data["Type 1"]=="Dark"]
Bug= data[data["Type 1"]=="Bug"]

# %% [markdown]
# Let's see the distribution of Attack and Defense columns according to species.

# %%
plt.scatter(Water.Attack,Water.Defense,color="red",label="Water")
plt.scatter(Steel.Attack,Steel.Defense,color="blue",label="Steel")
plt.scatter(Rock.Attack,Rock.Defense,color="green",label="Rock")
plt.scatter(Psychic.Attack,Psychic.Defense,color="red",label="Psychic")
plt.scatter(Poison.Attack,Poison.Defense,color="c",label="Poison")
plt.scatter(Normal.Attack,Normal.Defense,color="m",label="Normal")
plt.scatter(Ice.Attack,Ice.Defense,color="w",label="Ice")
plt.scatter(Ground.Attack,Ground.Defense,color="pink",label="Ground")
plt.scatter(Grass.Attack,Grass.Defense,color="orange",label="Grass")
plt.scatter(Ghost.Attack,Ghost.Defense,color="brown",label="Ghost")
plt.scatter(Fire.Attack,Fire.Defense,color="olive",label="Fire")
plt.scatter(Fighting.Attack,Fighting.Defense,color="teal",label="Fighting")
plt.scatter(Fairy.Attack,Fairy.Defense,color="tan",label="Fairy")
plt.scatter(Electric.Attack,Electric.Defense,color="tomato",label="Electric")
plt.scatter(Dragon.Attack,Dragon.Defense,color="yellow",label="Dragon")
plt.scatter(Dark.Attack,Dark.Defense,color="cyan",label="Dark")
plt.scatter(Bug.Attack,Bug.Defense,color="indigo",label="Bug")
plt.legend()
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.title("scatter plot")
plt.gcf().set_size_inches((10, 10))
plt.show()

# %% [markdown]
# Now let's see the histogram distributions by species.

# %%
plt.hist(Water.Attack,bins= 40,color="red")
plt.hist(Steel.Attack,bins= 40,color="blue")
plt.hist(Rock.Attack,bins= 40,color="green")
plt.hist(Psychic.Attack,bins= 40,color="gold")
plt.hist(Poison.Attack,bins= 40,color="c")
plt.hist(Normal.Attack,bins= 40,color="m")
plt.hist(Ice.Attack,bins=40,color="w")
plt.hist(Ground.Attack,bins= 40,color="pink")
plt.hist(Grass.Attack,bins= 40,color="orange")
plt.hist(Ghost.Attack,bins= 40,color="brown")
plt.hist(Fire.Attack,bins= 40,color="olive")
plt.hist(Fighting.Attack,bins= 40,color="teal")
plt.hist(Fairy.Attack,bins= 40,color="tan")
plt.hist(Electric.Attack,bins= 40,color="tomato")
plt.hist(Dragon.Attack,bins= 40,color="yellow")
plt.hist(Dark.Attack,bins= 40,color="cyan")
plt.hist(Bug.Attack,bins= 40,color="indigo")
plt.xlabel("values")
plt.ylabel("Sayı")
plt.title("Histogram Dağılımı")
plt.gcf().set_size_inches((10, 10))
plt.show()

# %% [markdown]
# now draw the line graph according to species.

# %%
plt.plot(Water.HP,Water.Speed,color="red",label= "Water")
plt.plot(Steel.HP,Steel.Speed,color="blue",label= "Steel")
plt.plot(Rock.HP,Rock.Speed,color="green",label= "Rock")
plt.plot(Psychic.HP,Psychic.Speed,color="gold",label= "Psychic")
plt.plot(Poison.HP,Poison.Speed,color="c",label= "Poison")
plt.plot(Normal.HP,Normal.Speed,color="m",label= "Normal")
plt.plot(Ice.HP,Ice.Speed,color="w",label= "Ice")
plt.plot(Ground.HP,Ground.Speed,color="pink",label= "Ground")
plt.plot(Grass.HP,Grass.Speed,color="orange",label= "Grass")
plt.plot(Ghost.HP,Ghost.Speed,color="brown",label= "Ghost")
plt.plot(Fire.HP,Fire.Speed,color="olive",label= "Fire")
plt.plot(Fighting.HP,Fighting.Speed,color="teal",label= "Fighting")
plt.plot(Fairy.HP,Fairy.Speed,color="tan",label= "Fairy")
plt.plot(Electric.HP,Electric.Speed,color="tomato",label= "Electric")
plt.plot(Dragon.HP,Dragon.Speed,color="yellow",label= "Dragon")
plt.plot(Dark.HP,Dark.Speed,color="cyan",label= "Dark")
plt.plot(Bug.HP,Bug.Speed,color="indigo",label= "Bug")
plt.gcf().set_size_inches((15, 15))
plt.legend()
plt.xlabel("HP")
plt.ylabel("Speed")
plt.show()

# %% [markdown]
# **In this article, I tried to examine the data set and visualize them.**
# **
# I am waiting for your positive or negative criticism.**
